# %% [markdown]
# These are my scikit learn notes, using neuralnines video

# %%
from logging import logAsyncioTasks
from sklearn.datasets import load_breast_cancer
 from sklearn.model_selection import train_test_split
 from sklearn.preprocessing import StandardScaler
 from sklearn.neighbors import KNeighborsClassifier

# %%
x,y = load_breast_cancer(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
knn = KNeighborsClassifier()
knn.fit(x_train_scaled, y_train)
# Out:
# [[1.314e+01 2.074e+01 8.598e+01 ... 1.181e-01 2.563e-01 8.174e-02]
#  [1.969e+01 2.125e+01 1.300e+02 ... 2.430e-01 3.613e-01 8.758e-02]
#  [1.122e+01 1.986e+01 7.194e+01 ... 2.022e-02 3.292e-01 6.522e-02]
#  ...
#  [1.175e+01 1.756e+01 7.589e+01 ... 1.010e-01 2.478e-01 7.757e-02]
#  [1.390e+01 1.662e+01 8.897e+01 ... 6.222e-02 2.679e-01 7.698e-02]
#  [1.017e+01 1.488e+01 6.455e+01 ... 2.579e-02 3.557e-01 8.020e-02]]

# %%
print(knn.score(x_test_scaled, y_test))
# Out:
# 0.9824561403508771

# %% [markdown]
# # Datasets

# %%
from sklearn.datasets import load_breast_cancer # differnece between load and fetch : load is pre installed, fetch is downloading from the internet
data = load_breast_cancer()

# %% [markdown]
# when calling the breast cancer function, return a massive dictionary. this dictionary has a couple differnet things, such as the x and y ( the actual data) and some meta data such as feature names, target names, and descriptions. there is a couple different ways to store this data.

# %%
x, y = load_breast_cancer(return_X_y=True)
#this returns two tuples. the return x y parameter is a way to automatically return the data,

# %%
x = data.data # the method data returns the dictionary called data in the breast cancer data set
y = data.target #this method target returns the dictionary called target in the breast cancer data set

# %%
df = load_breast_cancer(as_frame=True).frame #this returns a data frame. only need to store it in what object.
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.datasets import fetch_california_housing # downloading the dataset
df2 = fetch_california_housing(as_frame=True).frame

# %%
import matplotlib.pyplot as plt
#visualization
df.hist(figsize=(14,8))
plt.tight_layout()

# %%
from sklearn.datasets import make_blobs, make_moons # make basically makes you a data set with some uni distributions
x, y = make_blobs(5000, centers=5)
w, z = make_moons(noise = 0.2)

plt.scatter(x[:, 0], x[:, 1], c=y)
plt.scatter(w[:, 0], w[:, 1], c=z)

# %% [markdown]
# # Summary of datasets chapter
# this chapter covers how scikitlearn gets data. there is a couple methods, such as load, fetch and make
# load : already pre installed, sitting in the .datasets folder
# fetch : downloads data from the internet, i belive that they are like "preapproved" ones from sci kit learn
# make : makes you fake data.
